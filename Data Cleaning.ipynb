# %%
#package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv("NDA.csv")
NDA = data.copy()

# %%
#data cleaning
NDA[NDA['Category'] == "3/2"]["Text"]
# Out:
# Series([], Name: Text, dtype: object)

# %%
NDA.iloc[949, 1]
# Out:
# 'All Confidential or Proprietary Information in whatever form which has been transmitted to or made available to a Receiving Party by a Disclosing Party, and any copies thereof made by the Receiving Party, shall be returned to the Disclosing Party or destroyed promptly upon the Disclosing Party’s request therefor and, upon the Disclosing Party’s request, the Receiving Party shall certify in writing that it has complied with the foregoing (to the extent which such Party has been able to so comply) and is not aware of any violation of this Agreement.  Nothing herein shall require the Receiving Party to delete electronic copies of Confidential or Proprietary Information (including emails) that have been embedded in the Receiving Party’s electronic records systems through normal back-up procedures as long as such electronic copies of Confidential or Proprietary information (including emails) are kept confidential by Receiving Party pursuant to the terms of this Agreement.'

# %%
NDA['Category'].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
# Out:
#    Category                                               Text  Date  \
# 0         1  1. DEFINITIONS\n"Confidential Information" mea...   NaN
# 1         2  USE OF CONFIDENTIAL INFORMATION\nThe Recipient...   NaN
# 2        12  ACKNOWLEDGEMENT AND INDEMNITY\r\nThe Recipient...   NaN
# 3        13  RETURN OR DESTRUCTION OF CONFIDENTIAL INFORMAT...   NaN
# 4         4  DISCLAIMER\nThis Agreement does not obligate t...   NaN
# 5         7  GENERAL\r\nThe failure of a party at any time ...   NaN
# 6        13  RETURN OR DESTRUCTION OF CONFIDENTIAL INFORMAT...   NaN
# 7         2  2. USE OF CONFIDENTIAL INFORMATION\r\n2.1 The ...   NaN
# 8         1  Article 2 (Definition of Confidential Informat...  2021
# 9         2  Article 3 (Handling of Confidential Informatio...  2021
# 10       15  Article 4 (Limitation of Copying, etc.)\r\nWit...  2021
# 11        5  Article 6 (Ownership of Confidential Informati...  2021
# 12       16  Article 7 (Termination)\r\nIf Receiving Party ...  2021
# ...

# %%
data
# Out:
# 'Hello'
